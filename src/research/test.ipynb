# %%
import pandas as pd
df = pd.read_csv(r"F:\zizo\RTKCorrection\src\data\navigation\PostProcessed\ROVER_FullNavigation_parameters3.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   System                   24 non-null     object
#  1   PRN                      24 non-null     int64
#  2   Epoch (UTC)              24 non-null     object
#  3   Clock Bias (s)           24 non-null     float64
#  4   Clock Drift (s/s)        24 non-null     float64
#  5   Clock Drift Rate (s/s²)  24 non-null     float64
#  6   IODE                     24 non-null     float64
#  7   Crs (m)                  24 non-null     float64
#  8   Δn (rad/s)               24 non-null     float64
#  9   M0 (rad)                 24 non-null     float64
#  10  Cuc (rad)                24 non-null     float64
#  11  Eccentricity             24 non-null     float64
#  12  Cus (rad)                24 non-null     float64
#  13  √A (m^0.5)               24 non-null     float64
# ...

# %%
df.describe()
# Out:
#              PRN  Clock Bias (s)  Clock Drift (s/s)  Clock Drift Rate (s/s²)  \
# count  24.000000       24.000000       2.400000e+01                     24.0
# mean   13.875000        0.000052       2.794801e-12                      0.0
# std     8.502238        0.000352       7.028938e-12                      0.0
# min     2.000000       -0.000486      -9.094947e-12                      0.0
# 25%     7.750000       -0.000167      -1.932676e-12                      0.0
# 50%    13.500000        0.000062       4.206413e-12                      0.0
# 75%    21.000000        0.000291       9.436008e-12                      0.0
# max    30.000000        0.000717       1.261924e-11                      0.0
#
#              IODE    Crs (m)    Δn (rad/s)   M0 (rad)     Cuc (rad)  \
# count   24.000000  24.000000  2.400000e+01  24.000000  2.400000e+01
# mean    79.125000 -10.384115  4.690433e-09   0.735928 -5.849482e-07
# std     61.433819  55.519299  2.628949e-10   1.572621  2.871135e-06
# ...

# %%
df['Epoch (UTC)'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 24 entries, 0 to 23
# Series name: Epoch (UTC)
# Non-Null Count  Dtype
# --------------  -----
# 24 non-null     object
# dtypes: object(1)
# memory usage: 320.0+ bytes

# %%
import pandas as pd
import georinex as gr

# Read the observation file
obs_data = gr.load(r"F:\zizo\RTKCorrection\src\research\research_data\20240214-041908v2.obs")

# Display the data
df = obs_data.to_dataframe()
df.head()
# Out:
#                                        C1            L1        D1    S1
# time                    sv
# 2024-02-14 04:19:28.004 G02           NaN           NaN       NaN   NaN
#                         G04  2.183554e+07  8.941286e+07 -1607.162  48.0
#                         G07  2.403299e+07  9.841108e+07  1402.741  43.0
#                         G08  2.177553e+07  8.916716e+07   760.247  47.0
#                         G09  2.159509e+07  8.842827e+07   421.945  48.0

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\User\Desktop\test_RTK1.txt",sep='\t')
df.head()
# Out:
#    Time_seconds  SatelliteID           C1C           L1C       D1C   S1C  \
# 0         15568            4  2.183553e+07  1.147465e+08 -2062.373  44.0
# 1         15568            7  2.403299e+07  1.262942e+08  1800.175  46.0
# 2         15568            8  2.177553e+07  1.144312e+08   975.683  46.0
# 3         15568            9  2.159508e+07  1.134829e+08   541.655  49.0
# 4         15568           27  2.263255e+07  1.189348e+08 -1535.173  46.0
#
#             C2L           L2L       D2L   S2L  C2S  L2S  D2S  S2S
# 0  2.183554e+07  8.941286e+07 -1607.162  48.0  NaN  NaN  NaN  NaN
# 1  2.403299e+07  9.841108e+07  1402.741  43.0  NaN  NaN  NaN  NaN
# 2  2.177553e+07  8.916716e+07   760.247  47.0  NaN  NaN  NaN  NaN
# 3  2.159509e+07  8.842827e+07   421.945  48.0  NaN  NaN  NaN  NaN
# 4  2.263256e+07  9.267653e+07 -1196.272  46.0  NaN  NaN  NaN  NaN

# %%
import gnss_lib_py as glp

# %%
from gnss_lib_py.parsers import rinex_obs  # or similar
from gnss_lib_py.parsers import rinex_nav  # or similar

# paths to your files
obs_path = r"F:\zizo\RTKCorrection\src\data\observation\20240214-041908.obs"
#nav_path = r"F:\zizo\RTKCorrection\src\data\navigation\Raw\RoverSt
# ationNav.nav"

lol = glp.RinexObs(obs_path)
lol
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 8
#       5 obs_path = r"F:\zizo\RTKCorrection\src\data\observation\20240214-041908.obs"
#       6 #nav_path = r"F:\zizo\RTKCorrection\src\data\navigation\Raw\RoverStationNav.nav"
# ----> 8 lol = glp.RinexObs(obs_path)
#       9 lol
#
# File c:\Users\User\anaconda3\envs\RTK\lib\site-packages\gnss_lib_py\parsers\rinex_obs.py:48, in RinexObs.__init__(self, input_path)
#      36 def __init__(self, input_path):
#      37     """Loading Rinex observation files into a NavData based class.
#      38
#      39     Should input path to `.yyo` file.
#    (...)
#      45
#      46     """
# ---> 48     obs_file = gr.load(input_path).to_dataframe()
#      49     obs_header = gr.rinexheader(input_path)
#      50     obs_measure_types = obs_header['fields']
#
# ...
